# %% [markdown]
# <a href="https://colab.research.google.com/github/kalswjd/DA_School_1/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EC%8A%A4%EC%BF%A8_0512_01_%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://search.daum.net/search?w=tot&q=%EB%8B%A4%EC%9D%8C%20%EC%8B%A4%EC%8B%9C%EA%B0%84%20%EA%B2%80%EC%83%89%EC%96%B4&nzq=%EC%8B%A4%EC%8B%9C%EA%B0%84%20%EA%B2%80%EC%83%89%EC%96%B4&DA=RSJ"
response = requests.get(url)
#print(response.text)
soup = BeautifulSoup(response.content, 'html.parser', from_encoding='euc-kr')

# %%
print(soup.title)
print(soup.title.string)
# Out:
# <title>다음 실시간 검색어 – Daum 검색</title>
# 다음 실시간 검색어 – Daum 검색

# %%
print(response.text)
# Out:
# <!doctype html>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="ko" class="pc unix ">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta http-equiv="content-Type" content="text/html;charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta name="autocomplete" content="off" />
# <meta name="referrer" content="always">
# <meta name="format-detection" content="telephone=no" />
# <meta property="og:title" content="다음 실시간 검색어 &ndash; Daum 검색" />
# <meta property="og:url" content="https://search.daum.net/search?w=tot&q=%EB%8B%A4%EC%9D%8C%20%EC%8B%A4%EC%8B%9C%EA%B0%84%20%EA%B2%80%EC%83%89%EC%96%B4" />
# <meta property="og:description" content="Daum 검색에서 다음 실시간 검색어에 대한 최신정보를 찾아보세요." />
# <meta property="og:image" content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" />
# <meta property="og:site_name" content="다음검색" />
# <title>다음 실시간 검색어 &ndash; Daum 검색</title>
# ...

# %%
print(soup.findAll("a","link_txt"))
# Out:
# [<a class="link_txt" href="?w=tot&amp;DA=CQN&amp;q=%EB%AC%B8%EC%9E%AC%EC%9D%B8%EC%9E%85%EB%8B%88%EB%8B%A4&amp;rtmaxcoll=CQN,EM1&amp;169517" onclick="smartLog(this,'dc=CQN&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=1',event);">문재인입니다</a>, <a class="link_txt" href="?w=tot&amp;DA=CQN&amp;q=%EA%B0%80%EB%94%94%EC%96%B8%EC%A6%88%20%EC%98%A4%EB%B8%8C%20%EA%B0%A4%EB%9F%AD%EC%8B%9C%3A%20Volume%203&amp;rtmaxcoll=CQN,EM1&amp;129156" onclick="smartLog(this,'dc=CQN&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=2',event);">가디언즈 오브 갤럭시: Volume 3</a>, <a class="link_txt" href="?w=tot&amp;DA=CQN&amp;q=%EB%93%9C%EB%A6%BC&amp;rtmaxcoll=CQN,EM1&amp;135762" onclick="smartLog(this,'dc=CQN&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=3',event);">드림</a>, <a class="link_txt" href="?w=tot&amp;DA=CQN&amp;q=%EC%A1%B4%20%EC%9C%85%204&amp;rtmaxcoll=CQN,EM1&amp;162386" onclick="smartLog(this,'dc=CQN&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=4',event);">존 윅 4</a>, <a class="link_txt" href="?w=tot&amp;DA=CQN&amp
# ...

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url = "https://www.signal.bz/"
response = requests.get(url,headers=headers)
soup = BeautifulSoup(response.content, 'html.parser', from_encoding='euc-kr') 

rank = 1

results = soup.findAll("a","link_txt")

search_rank_file = open('rankresult.txt','w') 

print(datetime.today().strftime('%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n'))

for result in results:
    search_rank_file.write(str(rank)+'위:'+result.get_text()+'\n')
    print(rank,'위:',result.get_text(),'\n')
    rank  += 1
# Out:
# 2023년 05월 12일의 실시간 검색어 순위입니다.
#
# 1 위: 오페라의 유령
#
# 2 위: 맘마미아
#
# 3 위: 친정엄마
#
# 4 위: 모차르트!
#
# 5 위: 영웅
#
# 6 위: 베토벤 2
#
# 7 위: 광주
#
# 8 위: 데스노트
#
# 9 위: 레드북
#
# 10 위: 시카고 오리지널 내한
#
# 11 위: 미스터 로또
#
# 12 위: 텐트 밖은 유럽 노르웨이 편
#
# 13 위: 텐트 밖은 유럽 스페인 편
#
# 14 위: 팬텀싱어4
#
# 15 위: 나는 SOLO
#
# 16 위: 나 혼자 산다
#
# 17 위: 어서와 한국은 처음이지?
#
# 18 위: 트랄랄라 브라더스
#
# 19 위: 홍김동전
#
# 20 위: 꼬리에 꼬리를 무는 그날 이야기 시즌 2
#
# 21 위: 김태연 콘서트
#
# 22 위: 오페라의 유령
#
# 23 위: 맘마미아
#
# 24 위: 미스터트롯2 콘서트
#
# 25 위: 조용필 콘서트
#
# 26 위: 친정엄마
#
# 27 위: 불타는 트롯맨 콘서트
#
# 28 위: 모차르트!
#
# 29 위: 영웅
#
# 30 위: 성시경 콘서트
#
# 31 위: 다음 실시간 검색어 폐지
#
# 32 위: 다음 실시간 검색어 순위
#
# 33 위: 네이버 실시간 검색어
#
# 34 위: zum
#
# 35 위: 네이트
#
# 36 위: 줌
#
# 37 위: 실시간 검색어 사이트
#
# 38 위: 시그널 실시간 검색어
#
# 39 위: 단어 검색
#
# 40 위: 구글 실시간 검색어
#
# 41 위: 다음 분야별 검색어
#
# 42 위: 실시간 인기 검색어
#
# 43 위: 다음 사진 검색
#
# 44 위: 다음 실검
#
# 45 위: 블랙키위
#
# 46 위: 다음 사물검색
